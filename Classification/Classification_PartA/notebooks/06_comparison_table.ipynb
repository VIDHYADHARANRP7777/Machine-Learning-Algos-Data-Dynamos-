# %% [markdown]
# # Classification Track — Part A
# ## 06. Preliminary Comparison Table (Review 1)
#
# This notebook consolidates the results logged by notebooks `01`–`05` into the single comparison table required
# by the Review 1 rubric (Section D2) and deliverable D3. **This table currently covers the 5 Part-A algorithms only**;
# the remaining 5 algorithms (Random Forest, AdaBoost, Gradient Boosting, Bagging, MLP) are added in Part B for
# Review 2, at which point this becomes the full 10-algorithm consolidated comparison (deliverable D6).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
results = pd.read_csv("../results/part_a_results.csv")
results = results.sort_values("Accuracy", ascending=False).reset_index(drop=True)
results
# Out:
#                       Algorithm  Accuracy  Precision_weighted  \
# 0                 Decision Tree    0.9811              0.9814
# 1  Support Vector Machine (SVC)    0.9764              0.9773
# 2           K-Nearest Neighbors    0.9243              0.9230
# 3           Logistic Regression    0.9078              0.9088
# 4        Naive Bayes (Gaussian)    0.7447              0.7849
#
#    Recall_weighted  F1_weighted  ROC_AUC_OvR
# 0           0.9811       0.9810       0.9955
# 1           0.9764       0.9765       0.9989
# 2           0.9243       0.9229       0.9864
# 3           0.9078       0.9071       0.9921
# 4           0.7447       0.7351       0.9497

# %%
fig, ax = plt.subplots(figsize=(10, 5))
melted = results.melt(id_vars="Algorithm", value_vars=["Accuracy", "F1_weighted", "ROC_AUC_OvR"],
                       var_name="Metric", value_name="Score")
sns.barplot(data=melted, x="Algorithm", y="Score", hue="Metric", ax=ax)
ax.set_ylim(0, 1.05)
ax.set_title("Part A — Algorithm Comparison (Review 1)")
plt.xticks(rotation=20, ha='right')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.savefig("../results/fig_part_a_comparison.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# **Preliminary conclusion (Review 1):** Based on the table and chart above, note which algorithm currently
# leads on weighted F1-score and briefly discuss *why* — e.g. tree-based models tend to exploit the engineered
# `BMI` feature and its interaction with `Weight`/`Height` more effectively than distance-based or
# independence-assuming models. This ranking is preliminary — Part B (Review 2) will add five more, generally
# stronger, ensemble-based algorithms (Random Forest, AdaBoost, Gradient Boosting, Bagging, MLP) and may change
# the final leaderboard.
